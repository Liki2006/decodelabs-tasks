# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("Cleaned_Dataset.xlsx")
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
for col in df.select_dtypes(include="object"):
    print(col)
    print(df[col].unique())
    print("-"*40)

# %%
df.describe()

# %%
df.mean(numeric_only=True)
# Out:
# quantity            2.945833
# unit_price        356.412750
# items_in_cart       5.485000
# total_price      1053.968300
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# quantity           3.000
# unit_price       364.210
# items_in_cart      5.000
# total_price      823.615
# dtype: float64

# %%
df.mode(numeric_only=True)

# %%
df["total_price"].hist(bins=20)
plt.show()

# %%
df["quantity"].hist(bins=20)
plt.show()

# %%
df["unit_price"].hist(bins=20)
plt.show()

# %%
df["items_in_cart"].hist(bins=20)
plt.show()

# %%
sns.boxplot(x=df["total_price"])
plt.show()

# %%
sns.boxplot(x=df["quantity"])
plt.show()

# %%
sns.boxplot(x=df["unit_price"])
plt.show()

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.show()

# %%
df["payment_method"].value_counts()

# %%
sns.countplot(x="payment_method",data=df)
plt.show()

# %% [markdown]
# UPI is the most perferred payment methode

# %%
df["product_name"].value_counts()
# Out:
# product_name
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64

# %% [markdown]
# Printer is the most ordered product

# %%
df["order_status"].value_counts()
# Out:
# order_status
# Cancelled    250
# Returned     247
# Pending      237
# Shipped      235
# Delivered    231
# Name: count, dtype: int64

# %%
df["referral_source"].value_counts()
# Out:
# referral_source
# Instagram    259
# Email        250
# Google       241
# Facebook     228
# Referral     222
# Name: count, dtype: int64

# %% [markdown]
# Most customers come from instagram

# %%
#Time Analysis
df.groupby(df["order_date"].dt.month).size()

# %% [markdown]
# June month has the highest number of orders

# %%
df.groupby(df["order_date"].dt.day).size()
